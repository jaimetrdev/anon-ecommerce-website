# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimetrdev/anon-ecommerce-website/blob/master/Copia_de_C2_Machine_Learning_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DATA INGESTION

# %% [markdown]
# ---
#
#
# <font color='red'> Google Drive Set-Up </font>
#
#
# ---

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ---
#
#
# <font color='red'> Kaggle Set-Up </font>
#
#
# ---

# %%
# Install Kaggle in Colab:

# !pip install -U -q kaggle

# %%
# Create a folder named 'kaggle' in root folder:

# !mkdir -p ~/.kaggle

# %%
# Upload kaggle.json to Colab:

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5c04b698-15fd-4d77-9960-6a2fbc81f293" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c04b698-15fd-4d77-9960-6a2fbc81f293">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"thevictor23","key":"c8968e0d3f1fb2d658fbf2fe8e3e7b1f"}'}

# %%
# Copy kaggle.json into kaggle folder created above:

# !cp kaggle.json ~/.kaggle/

# %%
# API COMMAND

# !kaggle datasets download -d uciml/pima-indians-diabetes-database
# Out:
# ...
#   0% 0.00/8.91k [00:00<?, ?B/s]
# 100% 8.91k/8.91k [00:00<00:00, 7.37MB/s]

# %%
# !apt install pv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# Suggested packages:
#   doc-base
# The following NEW packages will be installed:
#   pv
# 0 upgraded, 1 newly installed, 0 to remove and 32 not upgraded.
# Need to get 48.3 kB of archives.
# After this operation, 123 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 pv amd64 1.6.6-1 [48.3 kB]
# Fetched 48.3 kB in 1s (50.6 kB/s)
# Selecting previously unselected package pv.
# (Reading database ... 155685 files and directories currently installed.)
# Preparing to unpack .../archives/pv_1.6.6-1_amd64.deb ...
# Unpacking pv (1.6.6-1) ...
# Setting up pv (1.6.6-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
#**************************************************
# UNZIPPING DATASET

#  kaggle datasets download -d uciml/pima-indians-diabetes-database

# !unzip /content/zddtpgzv63-4.zip

# !unzip -o /content/pima-indians-diabetes-database.zip -d /content/data | pv -l >/dev/nul
# Out:
# 2.00  0:00:00 [ 279 /s] [ <=>                                                  ]

# %% [markdown]
# ## EDA - EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
diabetes_data = pd.read_csv("diabetes.csv")

# %%
diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ## Features y Targets

# %%
X = diabetes_data.drop(columns=["Outcome"])

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y = diabetes_data["Outcome"]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 60             2       84              0              0        0   0.0
# 618            9      112             82             24        0  28.2
# 346            1      139             46             19       83  28.7
# 294            0      161             50              0        0  21.9
# 231            6      134             80             37      370  46.2
# ..           ...      ...            ...            ...      ...   ...
# 71             5      139             64             35      140  28.6
# 106            1       96            122              0        0  22.4
# 270           10      101             86             37        0  45.6
# 435            0      141              0              0        0  42.4
# 102            0      125             96              0        0  22.5
#
#      DiabetesPedigreeFunction  Age
# 60                      0.304   21
# 618                     1.282   50
# ...

# %%
# KNN = K Nearest Neighbors

from sklearn.neighbors import KNeighborsClassifier


test_scores = []
train_scores = []

for i in range(1,15):

    knn = KNeighborsClassifier(i)

    # Entrenamiento
    knn.fit(X_train,y_train)
    
    train_scores.append(knn.score(X_train,y_train))
    test_scores.append(knn.score(X_test,y_test))

# %%
for i, train_s, test_s in zip(range(1,15), train_scores, test_scores):

  print("KNN # de Componentes:", i, "Exactitud de Entrenamiento:", train_s, "Exactitud de Evaluacion:", test_s)
# Out:
# KNN # de Componentes: 1 Exactitud de Entrenamiento: 1.0 Exactitud de Evaluacion: 0.6753246753246753
# KNN # de Componentes: 2 Exactitud de Entrenamiento: 0.8322475570032574 Exactitud de Evaluacion: 0.7012987012987013
# KNN # de Componentes: 3 Exactitud de Entrenamiento: 0.8550488599348535 Exactitud de Evaluacion: 0.6493506493506493
# KNN # de Componentes: 4 Exactitud de Entrenamiento: 0.8094462540716613 Exactitud de Evaluacion: 0.7077922077922078
# KNN # de Componentes: 5 Exactitud de Entrenamiento: 0.7980456026058632 Exactitud de Evaluacion: 0.6623376623376623
# KNN # de Componentes: 6 Exactitud de Entrenamiento: 0.7882736156351792 Exactitud de Evaluacion: 0.7272727272727273
# KNN # de Componentes: 7 Exactitud de Entrenamiento: 0.7931596091205212 Exactitud de Evaluacion: 0.6883116883116883
# KNN # de Componentes: 8 Exactitud de Entrenamiento: 0.7768729641693811 Exactitud de Evaluacion: 0.7467532467532467
# ...
